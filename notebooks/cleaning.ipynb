# %% [markdown]
# ### Cleaning

# %%
# import pandas and dataframe
import pandas as pd 
import re

# %% [markdown]
# ##### Cleaning for Movie Data

# %%
# import csv as a df
df = pd.read_csv("../data/digital/movies.csv")
df.drop(labels=["certificate", "votes", "ACTOR 2", "metascore", "ACTOR 1", "DIRECTOR ", "ACTOR 3", "ACTOR 4", "GROSS COLLECTION"], axis=1, inplace=True)
df.columns = ["ranking", "name", "year", "runtime", "genre", "rating", "summary"]
df["summary_length"] =df['summary'].str.len()
df['year'] = df['year'].apply(pd.to_numeric, errors='coerce').apply(abs)
df['genre'] = df['genre'].apply(lambda x : x.split(",")).apply(lambda x: [item.strip() for item in x])
df.to_csv("../data/digital/cleaned_movies.csv")
df
# Out:
#      ranking                          name    year  runtime  \
# 0          1                      Jai Bhim  2021.0  164 min
# 1          2      The Shawshank Redemption  1994.0  142 min
# 2          3                 The Godfather  1972.0  175 min
# 3          4               The Dark Knight  2008.0  152 min
# 4          5        The Godfather: Part II  1974.0  202 min
# ..       ...                           ...     ...      ...
# 245      246  Mr. Smith Goes to Washington  1939.0  129 min
# 246      247            Gone with the Wind  1939.0  238 min
# 247      248         It Happened One Night  1934.0  105 min
# 248      249    The Passion of Joan of Arc  1928.0  114 min
# 249      250                   The General  1926.0   67 min
#
#                            genre  rating  \
# 0                 [Crime, Drama]     9.4
# 1                        [Drama]     9.3
# 2                 [Crime, Drama]     9.2
# 3         [Action, Crime, Drama]     9.0
# 4                 [Crime, Drama]     9.0
# ..                           ...     ...
# 245              [Comedy, Drama]     8.1
# 246    [Drama, History, Romance]     8.1
# 247            [Comedy, Romance]     8.1
# 248  [Biography, Drama, History]     8.1
# 249  [Action, Adventure, Comedy]     8.1
#
#                                                summary  summary_length
# 0    When a tribal man is arrested for a case of al...             121
# 1    Two imprisoned men bond over a number of years...             118
# 2    The Godfather follows Vito Corleone, Don of th...             119
# 3    When the menace known as the Joker wreaks havo...             189
# 4    The early life and career of Vito Corleone in ...             164
# ..                                                 ...             ...
# 245  A naive youth leader is appointed to fill a va...             239
# 246  The manipulative daughter of a Georgia plantat...             167
# 247  A renegade reporter trailing a young runaway h...             212
# 248  In 1431, Jeanne d'Arc is placed on trial on ch...             151
# 249  After being rejected by the Confederate milita...             239
#
# [250 rows x 8 columns]

# %% [markdown]
# #### Cleaing for tv shows

# %%
df = pd.read_csv("../data/digital/series.csv")
df.drop(labels=["VOTES"], axis=1, inplace=True)
df.columns = ["ranking", "name", "year", "certificate", "runtime_mins", "genre", "rating", "details", "actor_1", "actor_2", "actor_3", 'actor_4']
df['genre'] = df['genre'].apply(lambda x: x.split(",")).apply(lambda x: [item.strip() for item in x])
df[['start_year', 'end_year']] = df['year'].str.extract(r'\((\d{4})–(\d{4})\)')
df['start_year'] = df['start_year'].apply(pd.to_numeric)
df['end_year'] = df['end_year'].apply(pd.to_numeric)
df.loc[df['start_year'].isna(), 'start_year'] = df.loc[df['start_year'].isna(), 'year'].apply(pd.to_numeric, errors='coerce').apply(abs)
df.loc[~df['runtime_mins'].isna(),'runtime_mins'] = df.loc[~df['runtime_mins'].isna(), 'runtime_mins'].apply(lambda x: str(x).split(' ')[0]).astype(int)
df['runtime_mins'] = df['runtime_mins'].astype(float)
df.drop(labels=['year'], axis=1, inplace=True)
df.to_csv("../data/digital/cleaned_data.csv")
df
# Out:
#      ranking                               name certificate  runtime_mins  \
# 0          1                       Breaking Bad       TV-MA          49.0
# 1          2                    Game of Thrones       TV-MA          57.0
# 2          3                          Chernobyl       TV-MA         330.0
# 3          4                   Band of Brothers       TV-MA         594.0
# 4          5                           Sherlock       TV-14          88.0
# ..       ...                                ...         ...           ...
# 245      246                             Utopia       TV-MA          50.0
# 246      247  The Adventures of Sherlock Holmes       TV-PG          60.0
# 247      248                          Carnivàle       TV-MA          55.0
# 248      249                        Castlevania       TV-MA          23.0
# 249      250                         True Blood       TV-MA          55.0
#
#                               genre  rating  \
# 0          [Crime, Drama, Thriller]     9.4
# 1        [Action, Adventure, Drama]     9.2
# 2        [Drama, History, Thriller]     9.4
# 3             [Drama, History, War]     9.4
# 4           [Crime, Drama, Mystery]     9.1
# ..                              ...     ...
# 245        [Drama, Mystery, Sci-Fi]     8.4
# 246         [Crime, Drama, Mystery]     8.7
# 247       [Drama, Fantasy, Mystery]     8.4
# 248  [Animation, Action, Adventure]     8.3
# 249       [Drama, Fantasy, Mystery]     7.8
#
#                                                details               actor_1  \
# 0    A high school chemistry teacher diagnosed with...        Bryan Cranston
# 1    Nine noble families fight for control over the...         Emilia Clarke
# 2    In April 1986, an explosion at the Chernobyl n...        Jessie Buckley
# 3    The story of Easy Company of the U.S. Army 101...          Scott Grimes
# 4    A modern update finds the famous sleuth and hi...  Benedict Cumberbatch
# ..                                                 ...                   ...
# 245  After a group of people, who meet online, disc...          Adeel Akhtar
# 246  Sherlock Holmes and Dr Watson solve the myster...          Jeremy Brett
# 247  During the Great Depression, an Oklahoma farm ...   Michael J. Anderson
# 248  A vampire hunter fights to save a besieged cit...      Richard Armitage
# 249  Telepathic waitress Sookie Stackhouse encounte...           Anna Paquin
#
#               actor_2            actor_3               actor_4  start_year  \
# 0          Aaron Paul          Anna Gunn          Betsy Brandt      2008.0
# 1      Peter Dinklage      Kit Harington           Lena Headey      2011.0
# 2        Jared Harris  Stellan Skarsgård         Adam Nagaitis      2019.0
# 3        Damian Lewis     Ron Livingston          Shane Taylor      2001.0
# 4      Martin Freeman         Una Stubbs         Rupert Graves      2010.0
# ..                ...                ...                   ...         ...
# 245      Paul Higgins       Neil Maskell   Fiona O'Shaughnessy      2013.0
# 246       David Burke   Rosalie Williams           Eric Porter      1984.0
# 247  Adrienne Barbeau       Clancy Brown  Debra Christofferson      2003.0
# 248      James Callis  Alejandra Reynoso            Theo James      2017.0
# 249     Stephen Moyer       Sam Trammell          Ryan Kwanten      2008.0
#
#      end_year
# 0      2013.0
# 1      2019.0
# 2         NaN
# 3         NaN
# 4      2017.0
# ..        ...
# 245    2014.0
# 246    1985.0
# 247    2005.0
# 248    2021.0
# 249    2014.0
#
# [250 rows x 13 columns]

# %% [markdown]
# ##### Cleaning for video games

# %%
df = pd.read_csv("../data/digital/video_games.csv")
df.drop(labels=["VOTES "], axis=1, inplace=True)
df.columns = ["ranking", "name", "year", "genre", "rating", "summary", "director", "actor_1", "actor_2", "actor_3", "actor_4", "certificate"]
df['year'] = df['year'].str.extract(r'\((\d{4})').astype(int)
df['genre'] = df['genre'].str.split(",")
df.to_csv("../data/digital/cleaned_video_games.csv")
df
# Out:
#      ranking                                        name  year  \
# 0          1   The Witcher 3: Wild Hunt - Blood and Wine  2016
# 1          2                      Red Dead Redemption II  2018
# 2          3                    The Witcher 3: Wild Hunt  2015
# 3          4                              The Last of Us  2013
# 4          5              Mass Effect: Legendary Edition  2021
# ..       ...                                         ...   ...
# 245      246  The Legend of Zelda: A Link Between Worlds  2013
# 246      247                                  Black Mesa  2012
# 247      248             Assassin's Creed IV: Black Flag  2013
# 248      249        Ni no Kuni: Wrath of the White Witch  2011
# 249      250                               Borderlands 2  2012
#
#                               genre  rating  \
# 0      [Action,  Adventure,  Drama]     9.8
# 1      [Action,  Adventure,  Crime]     9.7
# 2      [Action,  Adventure,  Drama]     9.7
# 3      [Action,  Adventure,  Drama]     9.7
# 4     [Action,  Adventure,  Sci-Fi]     9.7
# ..                              ...     ...
# 245  [Action,  Adventure,  Fantasy]     8.7
# 246    [Action,  Sci-Fi,  Thriller]     8.7
# 247  [Action,  Adventure,  History]     8.7
# 248           [Adventure,  Fantasy]     8.7
# 249   [Action,  Adventure,  Comedy]     NaN
#
#                                                summary              director  \
# 0    Geralt is in the southern province of Toussain...  Konrad Tomaszkiewicz
# 1    Amidst the decline of the Wild West at the tur...  Benjamin Byron Davis
# 2    A monster hunter for hire embarks on an epic j...  Konrad Tomaszkiewicz
# 3    In a hostile, post-pandemic world, Joel and El...        Neil Druckmann
# 4    A compilation of the first three Mass Effect g...          Casey Hudson
# ..                                                 ...                   ...
# 245  Link is yet again tasked with restoring peace ...      Hiromasa Shikata
# 246  Scientist Gordon Freeman navigates through the...        Carlos Montero
# 247  A video game where you play as sailor, private...         Ashraf Ismail
# 248  Oliver discovers that his mother is not dead, ...      Kentaro Motomura
# 249  A new group of adventurers arrives on the fron...        Paul Hellquist
#
#               actor_1         actor_2               actor_3  \
# 0         Doug Cockle   MyAnna Buring       Antonia Bernath
# 1         Roger Clark    Rob Wiethoff  Cali Elizabeth Moore
# 2         Doug Cockle    Denise Gough              Jo Wyatt
# 3      Jeffrey Pierce  Ashley Johnson            Troy Baker
# 4          Seth Green     Steven Barr       Kimberly Brooks
# ..                ...             ...                   ...
# 245     Mitsuki Saiga  Ayumi Fujimura           Seiro Ogino
# 246      Adam Dravean    Cris Mertens     Michael Tsarouhas
# 247    Kate Fleetwood    Ralph Ineson         Stuart Martin
# 248       Adam Wilson     Lauren Mote          Louis Tamone
# 249  Lynn Andrews III  Yasemin Arslan          Justin Barad
#
#                 actor_4 certificate
# 0            Mark Noble         NaN
# 1                   NaN           M
# 2       Jaimi Barbakoff           M
# 3            Hana Hayes           M
# 4           Keith David           M
# ..                  ...         ...
# 245          Kei Hayami           E
# 246          Kevin Sisk         NaN
# 247  Michael McElhatton           M
# 248      Steffan Rhodri        E10+
# 249  Christopher Bevins           M
#
# [250 rows x 12 columns]

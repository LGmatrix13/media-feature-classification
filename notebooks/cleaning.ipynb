# %% [markdown]
# ### Cleaning

# %%
# import pandas and dataframe
import pandas as pd 
import re

# %% [markdown]
# ##### Cleaning for Movie Data

# %%
# import csv as a df
df = pd.read_csv("../data/movies/movies.csv")
df.drop(labels=["certificate", "votes", "ACTOR 2", "metascore", "ACTOR 1", "DIRECTOR ", "ACTOR 3", "ACTOR 4", "GROSS COLLECTION"], axis=1, inplace=True)
df.columns = ["ranking", "name", "year", "runtime", "genre", "rating", "summary"]
df["summary_length"] =df['summary'].str.len()
df['year'] = df['year'].apply(pd.to_numeric, errors='coerce').apply(abs)
df
# Out:
#      ranking                          name    year  runtime  \
# 0          1                      Jai Bhim  2021.0  164 min
# 1          2      The Shawshank Redemption  1994.0  142 min
# 2          3                 The Godfather  1972.0  175 min
# 3          4               The Dark Knight  2008.0  152 min
# 4          5        The Godfather: Part II  1974.0  202 min
# ..       ...                           ...     ...      ...
# 245      246  Mr. Smith Goes to Washington  1939.0  129 min
# 246      247            Gone with the Wind  1939.0  238 min
# 247      248         It Happened One Night  1934.0  105 min
# 248      249    The Passion of Joan of Arc  1928.0  114 min
# 249      250                   The General  1926.0   67 min
#
#                          genre  rating  \
# 0                 Crime, Drama     9.4
# 1                        Drama     9.3
# 2                 Crime, Drama     9.2
# 3         Action, Crime, Drama     9.0
# 4                 Crime, Drama     9.0
# ...

# %% [markdown]
# #### Cleaing for tv shows

# %%
df = pd.read_csv("../data/movies/series.csv")
df.drop(labels=["VOTES"], axis=1, inplace=True)
df.columns = ["ranking", "name", "year", "certificate", "runtime", "genre", "rating", "details", "actor_1", "actor_2", "actor_3"]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 df = pd.read_csv("../data/movies/series.csv")
#       2 df.drop(labels=["VOTES"], axis=1, inplace=True)
# ----> 3 df.columns = ["ranking", "name", "year", "certificate", "runtime", "genre", "rating", "details", "actor_1", "actor_2", "actor_3"]
#       4 df
#
# File c:\Users\GROSSMANLJ21\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File c:\Users\GROSSMANLJ21\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...
